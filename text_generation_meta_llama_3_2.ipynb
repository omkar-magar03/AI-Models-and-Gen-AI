# %% [markdown]
# ## Install following dependencies/packages:
#
# 1. `transformers`
# 2. `langchain`
# 3. `langchain-huggingface`
# 4. `huggingface_hub`
#
# For installing use following command in the google colab terminal:
# `pip install <package>`

# %%
# connecting this google colab notebook to my hugging face account
from google.colab import userdata
from huggingface_hub import login

hf_token = userdata.get('HF_TOKEN')
login(token=hf_token)  # Log in using the retrieved token

# %%
# checking if GPU is available
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# for clearing gpu cache
import gc
gc.collect() # Python's garbage collector
torch.cuda.empty_cache()

# %%
# because of this warnings will not get printed in the output window
from transformers.utils.logging import set_verbosity_error
set_verbosity_error()

# %%
# downloading model
from transformers import pipeline

model = pipeline(
    "text-generation",
    model="meta-llama/Llama-3.2-1B"
)
# Out:
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
# taking input from user
user_input = input("What can I help you with: ")
# Out:
# What can I help you with: Quantum computers

# %%
# Generate text
output = model(user_input)
print(output[0]['generated_text'])
# Out:
# Quantum computers are a very powerful tool that can solve a lot of problems that we can’t solve on classical computers. But, to be able to use them, we need to understand how they work. In this article, we will explain the basics of quantum computing and how it works.
# What is a Quantum Computer?
# A quantum computer is a computer that uses quantum mechanics to perform calculations. It is different from a classical computer in that it can perform operations that classical computers cannot.
# ...
